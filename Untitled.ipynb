# %%
1+1
# Out:
# 2

# %%
print('dupa')
# Out:
# dupa

# %%
import numpy as np
import matplotlib.pyplot as plt

N = 20
theta = np.linspace(0.0, 2 * np.pi, N, endpoint=False)
radii = 10 * np.random.rand(N)
width = np.pi / 4 * np.random.rand(N)

ax = plt.subplot(111, polar=True)
bars = ax.bar(theta, radii, width=width, bottom=0.0)

# Use custom colors and opacity
for r, bar in zip(radii, bars):
    bar.set_facecolor(plt.cm.jet(r / 10.))
    bar.set_alpha(0.5)

plt.show()

# %%
np.rank
# Out:
# <function numpy.core.fromnumeric.rank>

# %%
np.rank?

# %% [markdown]
# If $\{A_n \}$ is equal $$\mu=2\frac{1}{2}$$

# %%
pwd
# Out:
# 'C:\\Users\\Jakub'

# %%
ls
# Out:
#  Volume in drive C is Windows8_OS
#  Volume Serial Number is E47B-CA1C
#
#  Directory of C:\Users\Jakub
#
# 27.11.2017  20:03    <DIR>          .
# 27.11.2017  20:03    <DIR>          ..
# 06.10.2017  17:11    <DIR>          .anaconda
# 01.01.2014  18:51    <DIR>          .android
# 27.11.2017  18:39    <DIR>          .conda
# 27.11.2017  18:29                43 .condarc
# 27.11.2017  18:48               212 .gitconfig
# 27.11.2017  19:46    <DIR>          .ipynb_checkpoints
# 27.11.2017  19:46    <DIR>          .ipython
# 27.11.2017  19:59    <DIR>          .jupyter
# 15.02.2015  13:09    <DIR>          .latexdraw
# 27.11.2017  19:48    <DIR>          .matplotlib
# 09.06.2016  01:20    <DIR>          .oracle_jre_usage
# 06.11.2016  12:00    <DIR>          .Plays.tv
# 06.11.2016  12:00    <DIR>          .QtWebEngineProcess
# 30.05.2017  03:33               218 .recently-used.xbel
# 11.01.2014  21:13    <DIR>          .swt
# 27.11.2017  19:01    <DIR>          Anaconda3k
# 06.10.2017  17:14    <DIR>          AnacondaProjects
# 10.04.2014  22:33    <DIR>          Application Data
# 15.11.2017  18:15    <DIR>          Contacts
# 27.11.2017  18:47    <DIR>          Desktop
# 27.11.2017  18:49    <DIR>          Documents
# 27.11.2017  18:45    <DIR>          Downloads
# 09.06.2016  00:02    <DIR>          Dropbox
# 15.11.2017  18:15    <DIR>          Favorites
# 15.11.2017  18:15    <DIR>          Links
# 15.11.2017  18:15    <DIR>          Music
# 24.11.2017  17:47    <DIR>          OneDrive
# 15.11.2017  18:15    <DIR>          Pictures
# 10.10.2013  07:00    <DIR>          Roaming
# 15.11.2017  18:15    <DIR>          Saved Games
# 15.11.2017  18:15    <DIR>          Searches
# 23.05.2016  03:15    <DIR>          SkyDrive
# 16.02.2017  17:25    <DIR>          Tracing
# 27.11.2017  20:03            56 534 Untitled.ipynb
# 15.11.2017  18:15    <DIR>          Videos
#                4 File(s)         57 007 bytes
#               33 Dir(s)  15 136 571 392 bytes free

# %%
cat test.py
# Out:
#   File "<ipython-input-3-8389bda8d8cc>", line 1
#     cat test.py
#            ^
# SyntaxError: invalid syntax

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.random.randn(100)
plt.plot(x)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

ts_length = 100
epsilon_values = []   # Empty list

for i in range(ts_length):
    e = np.random.randn()
    epsilon_values.append(e)

plt.plot(epsilon_values, 'b-')
plt.show()

# %%
x = [10, 'foo', False] 
type(x)
# Out:
# list

# %%
x.append(2.5)
x
# Out:
# [10, 'foo', False, 2.5, 2.5, 2.5]

# %%
x.pop()
# Out:
# 2.5

# %%
x
# Out:
# [10, 'foo', False, 2.5, 2.5]

# %%
animals = ['dog', 'cat', 'bird']
for animal in animals:
    print("The plural of " + animal + " is " + animal + "s")
# Out:
# The plural of dog is dogs
# The plural of cat is cats
# The plural of bird is birds

# %%
import numpy as np
import matplotlib.pyplot as plt

ts_length = 100
epsilon_values = []
i = 0
while i < ts_length:
    e = np.random.randn()
    epsilon_values.append(e)
    i = i + 1
plt.plot(epsilon_values, 'b-')
plt.show()
